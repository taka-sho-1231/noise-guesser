# %%
import os

from scripts.noise_guesser import NoiseGuesser
from scripts.diffuser import Diffuser

# %% [markdown]
# Set hyperparameters

# %%
path_to_images_dir = 'images/'
num_timesteps = 1000
beta_start = 0.0001
beta_end = 0.02
image_size = 64

# %% [markdown]
# Set diffuser and noise_guesser

# %%
diffuser = Diffuser(num_timesteps, beta_start, beta_end)

# %%
noise_guesser = NoiseGuesser(path_to_images_dir, diffuser, image_size)

# %% [markdown]
# To use your image, please set its path (optional).

# %%
path_to_image = None

# %% [markdown]
# ### LET'S PLAY!

# %%
noise_guesser.play(path_to_image)
# Out:
# Answer: 752, Diff: 148, Diff in dB: 43.40523430789915, Square error: 21904
# Answer: 826, Diff: 74, Diff in dB: 37.384634394619525, Square error: 5476
# Answer: 159, Diff: 41, Diff in dB: 32.25567713439471, Square error: 1681
